# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\saurabh\\Desktop\\Newdat\\market_basket.csv" , header = None)

# %%
df.head(3)
# Out:
#         0          1        2               3             4   \
# 0   shrimp    almonds  avocado  vegetables mix  green grapes
# 1  burgers  meatballs     eggs             NaN           NaN
# 2  chutney        NaN      NaN             NaN           NaN
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN

# %%
# !pip install apyori

# %%
# Data Processing 
transactions = [] 
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset 
from apyori import apriori 
rules = apriori(transactions , 
              min_support = 0.003 ,     #(3items * 7 days in week)/(Total Rows in dataset 7501)
              min_confidence = 0.2 ,
              min_lift = 3 , 
              min_length = 2) 

#Visualizing the results 
a = list(rules) 
result = [list(a[i][0]) for i in range(0 , len(a))]

# %%
df.shape
# Out:
# (7501, 20)

# %%
result
# Out:
# [['light cream', 'chicken'],
#  ['mushroom cream sauce', 'escalope'],
#  ['pasta', 'escalope'],
#  ['honey', 'fromage blanc'],
#  ['ground beef', 'herb & pepper'],
#  ['ground beef', 'tomato sauce'],
#  ['olive oil', 'light cream'],
#  ['olive oil', 'whole wheat pasta'],
#  ['shrimp', 'pasta'],
#  ['avocado', 'milk', 'spaghetti'],
#  ['cake', 'milk', 'burgers'],
#  ['chocolate', 'turkey', 'burgers'],
#  ['milk', 'turkey', 'burgers'],
#  ['frozen vegetables', 'cake', 'tomatoes'],
#  ['ground beef', 'cereals', 'spaghetti'],
#  ['ground beef', 'milk', 'chicken'],
#  ['light cream', 'nan', 'chicken'],
#  ['olive oil', 'milk', 'chicken'],
#  ['olive oil', 'spaghetti', 'chicken'],
#  ['frozen vegetables', 'chocolate', 'shrimp'],
#  ['ground beef', 'chocolate', 'herb & pepper'],
#  ['chocolate', 'soup', 'milk'],
#  ['ground beef', 'spaghetti', 'cooking oil'],
#  ['ground beef', 'eggs', 'herb & pepper'],
#  ['spaghetti', 'eggs', 'red wine'],
#  ['mushroom cream sauce', 'nan', 'escalope'],
#  ['nan', 'pasta', 'escalope'],
#  ['french fries', 'ground beef', 'herb & pepper'],
#  ['nan', 'honey', 'fromage blanc'],
#  ['frozen vegetables', 'green tea', 'tomatoes'],
#  ['frozen vegetables', 'ground beef', 'spaghetti'],
#  ['frozen vegetables', 'olive oil', 'milk'],
#  ['frozen vegetables', 'milk', 'soup'],
#  ['frozen vegetables', 'milk', 'tomatoes'],
#  ['frozen vegetables', 'mineral water', 'shrimp'],
#  ['frozen vegetables', 'olive oil', 'spaghetti'],
#  ['frozen vegetables', 'spaghetti', 'shrimp'],
#  ['frozen vegetables', 'shrimp', 'tomatoes'],
#  ['frozen vegetables', 'spaghetti', 'tomatoes'],
#  ['ground beef', 'grated cheese', 'spaghetti'],
#  ['ground beef', 'green tea', 'tomatoes'],
#  ['ground beef', 'herb & pepper', 'milk'],
#  ['ground beef', 'mineral water', 'herb & pepper'],
#  ['ground beef', 'nan', 'herb & pepper'],
#  ['ground beef', 'herb & pepper', 'spaghetti'],
#  ['ground beef', 'milk', 'olive oil'],
#  ['ground beef', 'milk', 'soup'],
#  ['ground beef', 'nan', 'tomato sauce'],
#  ['pepper', 'ground beef', 'spaghetti'],
#  ['spaghetti', 'ground beef', 'shrimp'],
#  ['ground beef', 'spaghetti', 'tomato sauce'],
#  ['spaghetti', 'light cream', 'mineral water'],
#  ['olive oil', 'light cream', 'nan'],
#  ['olive oil', 'milk', 'shrimp'],
#  ['olive oil', 'milk', 'soup'],
#  ['olive oil', 'milk', 'spaghetti'],
#  ['milk', 'soup', 'tomatoes'],
#  ['whole wheat pasta', 'milk', 'spaghetti'],
#  ['olive oil', 'mineral water', 'soup'],
#  ['olive oil', 'mineral water', 'whole wheat pasta'],
#  ['olive oil', 'nan', 'whole wheat pasta'],
#  ['nan', 'shrimp', 'pasta'],
#  ['olive oil', 'pancakes', 'spaghetti'],
#  ['olive oil', 'spaghetti', 'tomatoes'],
#  ['whole wheat rice', 'spaghetti', 'tomatoes'],
#  ['avocado', 'nan', 'milk', 'spaghetti'],
#  ['cake', 'nan', 'milk', 'burgers'],
#  ['nan', 'chocolate', 'turkey', 'burgers'],
#  ['nan', 'milk', 'turkey', 'burgers'],
#  ['frozen vegetables', 'cake', 'nan', 'tomatoes'],
#  ['ground beef', 'nan', 'cereals', 'spaghetti'],
#  ['ground beef', 'nan', 'milk', 'chicken'],
#  ['olive oil', 'nan', 'milk', 'chicken'],
#  ['olive oil', 'nan', 'spaghetti', 'chicken'],
#  ['ground beef', 'eggs', 'chocolate', 'mineral water'],
#  ['frozen vegetables', 'ground beef', 'mineral water', 'chocolate'],
#  ['frozen vegetables', 'ground beef', 'chocolate', 'spaghetti'],
#  ['frozen vegetables', 'mineral water', 'chocolate', 'milk'],
#  ['frozen vegetables', 'chocolate', 'spaghetti', 'milk'],
#  ['frozen vegetables', 'mineral water', 'chocolate', 'shrimp'],
#  ['frozen vegetables', 'nan', 'chocolate', 'shrimp'],
#  ['ground beef', 'nan', 'chocolate', 'herb & pepper'],
#  ['nan', 'chocolate', 'soup', 'milk'],
#  ['olive oil', 'mineral water', 'chocolate', 'spaghetti'],
#  ['spaghetti', 'mineral water', 'chocolate', 'shrimp'],
#  ['ground beef', 'nan', 'spaghetti', 'cooking oil'],
#  ['frozen vegetables', 'eggs', 'milk', 'mineral water'],
#  ['ground beef', 'eggs', 'herb & pepper', 'nan'],
#  ['spaghetti', 'eggs', 'nan', 'red wine'],
#  ['french fries', 'ground beef', 'nan', 'herb & pepper'],
#  ['mineral water', 'frozen smoothie', 'spaghetti', 'milk'],
#  ['frozen vegetables', 'nan', 'green tea', 'tomatoes'],
#  ['frozen vegetables', 'ground beef', 'mineral water', 'milk'],
#  ['frozen vegetables', 'ground beef', 'milk', 'spaghetti'],
#  ['frozen vegetables', 'ground beef', 'mineral water', 'spaghetti'],
#  ['frozen vegetables', 'ground beef', 'nan', 'spaghetti'],
#  ['frozen vegetables', 'olive oil', 'mineral water', 'milk'],
#  ['frozen vegetables', 'mineral water', 'milk', 'soup'],
#  ['frozen vegetables', 'mineral water', 'milk', 'spaghetti'],
#  ['frozen vegetables', 'olive oil', 'nan', 'milk'],
#  ['frozen vegetables', 'nan', 'milk', 'soup'],
#  ['frozen vegetables', 'nan', 'milk', 'tomatoes'],
#  ['frozen vegetables', 'mineral water', 'nan', 'shrimp'],
#  ['frozen vegetables', 'mineral water', 'spaghetti', 'shrimp'],
#  ['frozen vegetables', 'mineral water', 'spaghetti', 'tomatoes'],
#  ['frozen vegetables', 'olive oil', 'nan', 'spaghetti'],
#  ['frozen vegetables', 'nan', 'spaghetti', 'shrimp'],
#  ['frozen vegetables', 'nan', 'shrimp', 'tomatoes'],
#  ['frozen vegetables', 'nan', 'spaghetti', 'tomatoes'],
#  ['ground beef', 'grated cheese', 'nan', 'spaghetti'],
#  ['ground beef', 'nan', 'green tea', 'tomatoes'],
#  ['ground beef', 'nan', 'herb & pepper', 'milk'],
#  ['ground beef', 'mineral water', 'herb & pepper', 'nan'],
#  ['ground beef', 'nan', 'herb & pepper', 'spaghetti'],
#  ['ground beef', 'mineral water', 'milk', 'spaghetti'],
#  ['ground beef', 'nan', 'milk', 'olive oil'],
#  ['ground beef', 'nan', 'milk', 'soup'],
#  ['spaghetti', 'ground beef', 'mineral water', 'olive oil'],
#  ['ground beef', 'mineral water', 'pancakes', 'spaghetti'],
#  ['ground beef', 'mineral water', 'spaghetti', 'tomatoes'],
#  ['pepper', 'ground beef', 'nan', 'spaghetti'],
#  ['spaghetti', 'ground beef', 'nan', 'shrimp'],
#  ['ground beef', 'nan', 'spaghetti', 'tomato sauce'],
#  ['spaghetti', 'light cream', 'nan', 'mineral water'],
#  ['olive oil', 'mineral water', 'milk', 'spaghetti'],
#  ['mineral water', 'milk', 'spaghetti', 'tomatoes'],
#  ['olive oil', 'nan', 'milk', 'shrimp'],
#  ['olive oil', 'nan', 'milk', 'soup'],
#  ['olive oil', 'nan', 'milk', 'spaghetti'],
#  ['nan', 'milk', 'soup', 'tomatoes'],
#  ['whole wheat pasta', 'nan', 'milk', 'spaghetti'],
#  ['olive oil', 'mineral water', 'nan', 'soup'],
#  ['olive oil', 'mineral water', 'nan', 'whole wheat pasta'],
#  ['olive oil', 'nan', 'pancakes', 'spaghetti'],
#  ['olive oil', 'nan', 'spaghetti', 'tomatoes'],
#  ['whole wheat rice', 'nan', 'spaghetti', 'tomatoes'],
#  ['nan', 'chocolate', 'eggs', 'mineral water', 'ground beef'],
#  ['nan', 'chocolate', 'mineral water', 'frozen vegetables', 'ground beef'],
#  ['nan', 'chocolate', 'frozen vegetables', 'ground beef', 'spaghetti'],
#  ['nan', 'chocolate', 'mineral water', 'frozen vegetables', 'milk'],
#  ['nan', 'chocolate', 'frozen vegetables', 'milk', 'spaghetti'],
#  ['nan', 'chocolate', 'mineral water', 'shrimp', 'frozen vegetables'],
#  ['nan', 'chocolate', 'olive oil', 'mineral water', 'spaghetti'],
#  ['nan', 'chocolate', 'mineral water', 'shrimp', 'spaghetti'],
#  ['nan', 'eggs', 'mineral water', 'frozen vegetables', 'milk'],
#  ['nan', 'mineral water', 'frozen smoothie', 'milk', 'spaghetti'],
#  ['nan', 'mineral water', 'frozen vegetables', 'ground beef', 'milk'],
#  ['nan', 'frozen vegetables', 'ground beef', 'milk', 'spaghetti'],
#  ['nan', 'mineral water', 'frozen vegetables', 'ground beef', 'spaghetti'],
#  ['nan', 'olive oil', 'mineral water', 'frozen vegetables', 'milk'],
#  ['nan', 'mineral water', 'soup', 'frozen vegetables', 'milk'],
#  ['nan', 'mineral water', 'frozen vegetables', 'milk', 'spaghetti'],
#  ['nan', 'mineral water', 'shrimp', 'frozen vegetables', 'spaghetti'],
#  ['nan', 'mineral water', 'tomatoes', 'frozen vegetables', 'spaghetti'],
#  ['nan', 'mineral water', 'ground beef', 'milk', 'spaghetti'],
#  ['nan', 'olive oil', 'mineral water', 'ground beef', 'spaghetti'],
#  ['nan', 'mineral water', 'ground beef', 'pancakes', 'spaghetti'],
#  ['nan', 'mineral water', 'tomatoes', 'ground beef', 'spaghetti'],
#  ['nan', 'olive oil', 'mineral water', 'milk', 'spaghetti'],
#  ['nan', 'mineral water', 'tomatoes', 'milk', 'spaghetti']]
